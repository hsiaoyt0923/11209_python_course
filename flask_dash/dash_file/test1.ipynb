# %%
import pandas as pd
import datasource

# %%
latest_data = datasource.lastest_datetime_data()
latest_df = pd.DataFrame(latest_data, columns=['站點名稱','更新時間','行政區','地址','總數','可借','可還'])
latest_df
# Out:
#                         站點名稱                 更新時間  行政區             地址  總數  可借  \
# 0            YouBike2.0_華聲公園  2023-12-01 09:17:09  士林區   華聲街17號(南側路側)  27   0
# 1         YouBike2.0_捷運科技大樓站  2023-12-01 09:17:09  大安區    復興南路二段235號前  28   1
# 2     YouBike2.0_復興南路二段273號前  2023-12-01 09:17:09  大安區   復興南路二段273號西側  21   0
# 3       YouBike2.0_國北教大實小東側門  2023-12-01 09:17:09  大安區    和平東路二段96巷7號  16  12
# 4          YouBike2.0_和平公園東側  2023-12-01 09:17:09  大安區  和平東路二段118巷33號  11   3
# ...                      ...                  ...  ...            ...  ..  ..
# 1494     YouBike2.0_國北教大側門南側  2023-12-06 16:06:05  大安區         敦南街51號  25  16
# 1495      YouBike2.0_和平實小東北側  2023-12-06 16:06:05  大安區         敦南街73號  13   3
# 1496    YouBike2.0_大安區健康服務中心  2023-12-06 16:06:05  大安區       辛亥路三段15號  15   0
# 1497       YouBike2.0_辛亥泰順街口  2023-12-06 16:06:15  大安區      辛亥泰順街口東南側  20   1
# 1498         YouBike2.0_芳和國中  2023-12-06 16:06:15  大安區     臥龍街170號(前)  28  19
#
#       可還
# 0     27
# 1     26
# 2     21
# 3      4
# 4      8
# ...   ..
# 1494   9
# 1495  10
# 1496  15
# 1497  19
# 1498   9
#
# [1499 rows x 7 columns]

# %%
latest_df1 = latest_df['站點名稱'].map(lambda name:name[11:])

# %%
latest_df1
# Out:
# 0              華聲公園
# 1           捷運科技大樓站
# 2       復興南路二段273號前
# 3         國北教大實小東側門
# 4            和平公園東側
#            ...
# 1494       國北教大側門南側
# 1495        和平實小東北側
# 1496      大安區健康服務中心
# 1497         辛亥泰順街口
# 1498           芳和國中
# Name: 站點名稱, Length: 1499, dtype: object
